# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./Yes_Bank_Training.csv')

# %%
data = pd.read_csv('./Yes_Bank_Test.csv')

# %%
test_data.head()
# Out:
#    serial_number  age_in_years job_description marital_status  \
# 0              1            33          admin.        married
# 1              2            40      management        married
# 2              3            30      technician         single
# 3              4            44     blue-collar        married
# 4              5            35      technician        married
#
#   education_details has_default  balance_in_account housing_status  \
# 0         secondary          no                 796            yes
# 1         secondary          no                 754             no
# 2         secondary          no               10152            yes
# 3         secondary          no                 545            yes
# 4         secondary          no                5553            yes
#
#   previous_loan phone_type  date month_of_year  call_duration  \
# 0            no  telephone     6           apr            216
# ...

# %%
data.head()
# Out:
#    serial_number  age_in_years job_description marital_status  \
# 0              1            33          admin.        married
# 1              2            40      management        married
# 2              3            30      technician         single
# 3              4            44     blue-collar        married
# 4              5            35      technician        married
#
#   education_details has_default  balance_in_account housing_status  \
# 0         secondary          no                 796            yes
# 1         secondary          no                 754             no
# 2         secondary          no               10152            yes
# 3         secondary          no                 545            yes
# 4         secondary          no                5553            yes
#
#   previous_loan phone_type  date month_of_year  call_duration  \
# 0            no  telephone     6           apr            216
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['job_description'] = le.fit_transform(data['job_description'])
print(le.classes_)
data['marital_status'] = le.fit_transform(data['marital_status'])
print(le.classes_)
data['education_details'] = le.fit_transform(data['education_details'])
print(le.classes_)
data['has_default'] = le.fit_transform(data['has_default'])
print(le.classes_)
data['housing_status'] = le.fit_transform(data['housing_status'])
print(le.classes_)
data['previous_loan'] = le.fit_transform(data['previous_loan'])
print(le.classes_)
data['phone_type'] = le.fit_transform(data['phone_type'])
print(le.classes_)
data['month_of_year'] = le.fit_transform(data['month_of_year'])
print(le.classes_)
data['poutcome_of_campaign'] = le.fit_transform(data['poutcome_of_campaign'])
print(le.classes_)
data['outcome'] = le.fit_transform(data['outcome'])
print(le.classes_)
# Out:
# ['admin.' 'blue-collar' 'entrepreneur' 'housemaid' 'management' 'retired'
#  'self-employed' 'services' 'student' 'technician' 'unemployed' 'unknown']
# ['divorced' 'married' 'single']
# ['primary' 'secondary' 'tertiary' 'unknown']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['cellular' 'telephone' 'unknown']
# ['apr' 'aug' 'dec' 'feb' 'jan' 'jul' 'jun' 'mar' 'may' 'nov' 'oct']
# ['failure' 'other' 'success' 'unknown']
# ['no' 'yes']

# %%
le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
np.unique(data['poutcome_of_campaign'].values)
# Out:
# array([0, 1, 2, 3])

# %%
data.head()
# Out:
#    serial_number  age_in_years  job_description  marital_status  \
# 0              1            33                0               1
# 1              2            40                4               1
# 2              3            30                9               2
# 3              4            44                1               1
# 4              5            35                9               1
#
#    education_details  has_default  balance_in_account  housing_status  \
# 0                  1            0                 796               1
# 1                  1            0                 754               0
# 2                  1            0               10152               1
# 3                  1            0                 545               1
# 4                  1            0                5553               1
#
#    previous_loan  phone_type  date  month_of_year  call_duration  \
# 0              0           1     6              0            216
# ...

# %%
data.columns
# Out:
# Index(['serial_number', 'age_in_years', 'job_description', 'marital_status',
#        'education_details', 'has_default', 'balance_in_account',
#        'housing_status', 'previous_loan', 'phone_type', 'date',
#        'month_of_year', 'call_duration', 'campaign_contacts', 'days_passed',
#        'previous_contact', 'poutcome_of_campaign'],
#       dtype='object')

# %%
data.values.shape
# Out:
# (13562, 17)

# %%
x_data, y_data = data.drop(axis=0, columns=['outcome', 'serial_number']), data['outcome']

# %%
x_data = data.drop(axis=0, columns=['serial_number'])

# %%
x_data.head()
# Out:
#    age_in_years  job_description  marital_status  education_details  \
# 0            33                0               1                  1
# 1            40                4               1                  1
# 2            30                9               2                  1
# 3            44                1               1                  1
# 4            35                9               1                  1
#
#    has_default  balance_in_account  housing_status  previous_loan  phone_type  \
# 0            0                 796               1              0           1
# 1            0                 754               0              1           0
# 2            0               10152               1              0           0
# 3            0                 545               1              0           0
# 4            0                5553               1              0           0
#
#    date  month_of_year  call_duration  campaign_contacts  days_passed  \
# ...

# %%
x_data.head()
# Out:
#    age_in_years  job_description  marital_status  education_details  \
# 0            58                4               1                  2
# 1            44                9               2                  1
# 2            33                2               1                  1
# 3            47                1               1                  3
# 4            33               11               2                  3
#
#    has_default  balance_in_account  housing_status  previous_loan  phone_type  \
# 0            0                2143               1              0           2
# 1            0                  29               1              0           2
# 2            0                   2               1              1           2
# 3            0                1506               1              0           2
# 4            0                   1               0              0           2
#
#    date  month_of_year  call_duration  campaign_contacts  days_passed  \
# ...

# %%
y_data.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: outcome, dtype: int32

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(test_size=0.1)
for train_ix, test_ix in sss.split(X=x_data.values, y=y_data.values):
    x_train, y_train = x_data.values[train_ix], y_data.values[train_ix]
    x_val, y_val = x_data.values[test_ix], y_data.values[test_ix]

# %%
x_train.shape, x_val.shape
# Out:
# ((28484, 16), (3165, 16))

# %%
sss1 = StratifiedShuffleSplit(test_size=0.2)
for train_ix, test_ix in sss1.split(X=x_train, y=y_train):
    xx_train, yy_train = x_train[train_ix], y_train[train_ix]
    x_test, y_test = x_train[test_ix], y_train[test_ix]

# %%
xx_train.shape, x_test.shape
# Out:
# ((22787, 16), (5697, 16))

# %%
x_data.corr()
# Out:
#                       age_in_years  job_description  marital_status  \
# age_in_years              1.000000        -0.018437       -0.375747
# job_description          -0.018437         1.000000        0.044833
# marital_status           -0.375747         0.044833        1.000000
# education_details        -0.093187         0.162700        0.093332
# has_default              -0.022041        -0.007526        0.000845
# balance_in_account        0.083344         0.011894        0.005298
# housing_status           -0.173562        -0.101029       -0.000955
# previous_loan            -0.008175        -0.031356       -0.034624
# phone_type               -0.011457        -0.120075       -0.007343
# date                     -0.025832         0.020759       -0.004132
# month_of_year            -0.063415        -0.140837       -0.012787
# call_duration            -0.038859        -0.003134        0.016283
# campaign_contacts        -0.000308         0.009576        0.008664
# ...

# %%
from sklearn.svm import SVC

# %%
classifier = SVC(kernel="rbf", gamma=5, C=0.001)

# %%
classifier.fit(X=xx_train, y=yy_train)
# Out:
# SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y = classifier.predict(X=x_data.values)

# %%
y.shape
# Out:
# (13562,)

# %%
z = le.inverse_transform(y)

# %%
np.unique(z)
# Out:
# array(['no'], dtype=object)

# %%
df = pd.DataFrame(z, columns=['outcome'])

# %%
df.head()
# Out:
#   outcome
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no

# %%
df.dtypes
# Out:
# outcome    object
# dtype: object

# %%
df1 = pd.DataFrame([i for i in range(1,len(z)+1)], columns=['serial_number'], dtype=np.int32)

# %%
df1.head()
# Out:
#    serial_number
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
df1.dtypes
# Out:
# serial_number    int32
# dtype: object

# %%
solu = pd.concat([df1, df], axis=1)

# %%
solu.to_csv('./sample_submission.csv',index=False)
